# %%
import matplotlib.pyplot as plt
import scipy.constants as cons
import pandas as pd
import numpy as np
import scipy
import cmath
import time
import os

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from qutip import *

# Column Heads for data output
columns=['Wigint', 'WLN', 'SqzFactor', 'DisFactor', 'Xrange', 'Xstep', 'Yrange', 'Ystep', 'N','Time']

# %%
# Very Basic Data ploting, not enough data yet, need to do for higher squeezing factors to see saturation and 
# maybe do finer iteratino over sqf
subdf = pd.read_csv('photonsubbed.csv')

# %%
subdf
# Out:
#       Wigint       WLN  SqzFactor  DisFactor       Xrange  Xstep       Yrange  \
# 0   0.999948 -0.000075        0.0          1  [-1.5, 4.5]   0.01      [-3, 3]
# 1   0.999831 -0.000244        0.1          1  [-1.5, 4.5]   0.01      [-3, 3]
# 2   0.999903 -0.000139        0.2          1  [-1.5, 4.5]   0.01  [-3.5, 3.5]
# 3   0.999399 -0.000358        0.3          1  [-1.5, 4.5]   0.01  [-3.5, 3.5]
# 4   0.999476  0.006297        0.4          1  [-1.5, 4.5]   0.01      [-4, 4]
# 5   0.999899  0.026980        0.5          1  [-1.5, 4.5]   0.01      [-5, 5]
# 6   0.999372  0.059978        0.6          1  [-1.5, 4.5]   0.01      [-5, 5]
# 7   0.999773  0.103276        0.7          1    [-0.5, 3]   0.01      [-6, 6]
# 8   0.999903  0.150097        0.8          1    [-0.5, 3]   0.01      [-7, 7]
# 9   0.999996  0.196870        0.9          1    [-0.5, 3]   0.01      [-9, 9]
# 10  0.999615  0.240578        1.0          1       [0, 3]   0.01      [-8, 8]
#
#     Ystep    N       Time
# 0    0.05  100   4.273024
# 1    0.05  100   4.212134
# 2    0.05  120   8.242064
# 3    0.05  120   7.771322
# 4    0.05  120   9.239460
# 5    0.05  120  10.940586
# 6    0.05  140  15.191053
# 7    0.05  140  10.894176
# 8    0.05  150  15.694458
# 9    0.05  150  18.911162
# 10   0.05  180  20.914007

# %%
WLN = subdf['WLN']
sqf = subdf['SqzFactor']

# %%
plt.plot(sqf, WLN)
